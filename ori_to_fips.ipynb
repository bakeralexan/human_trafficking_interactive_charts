# %%
import pandas as pd
import numpy as np
import os

# %%
fips_file = "Resources/fips_for_ori_processing.csv"
ori_file = "Resources/ht_for_ori_processing.csv"

# %%
ori_df = pd.read_csv(ori_file)
ori_df.head()
# Out:
#    DATA_YEAR        ORI                  PUB_AGENCY_NAME  PUB_AGENCY_UNIT  \
# 0       2020  GA0440200  DeKalb County Police Department              NaN
# 1       2020  GA0440200  DeKalb County Police Department              NaN
# 2       2020  GA0440200  DeKalb County Police Department              NaN
# 3       2020  GA0440200  DeKalb County Police Department              NaN
# 4       2020  GA0440200  DeKalb County Police Department              NaN
#
#   AGENCY_TYPE_NAME STATE_ABBR STATE_NAME   DIVISION_NAME COUNTY_NAME  \
# 0           County         GA    Georgia  South Atlantic      DEKALB
# 1           County         GA    Georgia  South Atlantic      DEKALB
# 2           County         GA    Georgia  South Atlantic      DEKALB
# 3           County         GA    Georgia  South Atlantic      DEKALB
# 4           County         GA    Georgia  South Atlantic      DEKALB
#
#   REGION_NAME POPULATION_GROUP_CODE         POPULATION_GROUP_DESC  \
# 0       South                    9A  MSA counties 100,000 or over
# 1       South                    9A  MSA counties 100,000 or over
# 2       South                    9A  MSA counties 100,000 or over
# 3       South                    9A  MSA counties 100,000 or over
# 4       South                    9A  MSA counties 100,000 or over
#
#    OFFENSE_SUBCAT_ID       OFFENSE_NAME    OFFENSE_SUBCAT_NAME  ACTUAL_COUNT  \
# 0                 81  Human Trafficking    Commercial Sex Acts             2
# 1                 82  Human Trafficking  Involuntary Servitude             1
# 2                 81  Human Trafficking    Commercial Sex Acts             2
# 3                 81  Human Trafficking    Commercial Sex Acts             5
# 4                 82  Human Trafficking  Involuntary Servitude             1
#
#    UNFOUNDED_COUNT  CLEARED_COUNT  JUVENILE_CLEARED_COUNT
# 0                0              0                       0
# 1                0              0                       0
# 2                0              1                       0
# 3                0              0                       0
# 4                0              0                       0

# %%
fips_df = pd.read_csv(fips_file)
fips_df.head()
# Out:
#    FIPS     Name State
# 0  1001  Autauga    AL
# 1  1003  Baldwin    AL
# 2  1005  Barbour    AL
# 3  1007     Bibb    AL
# 4  1009   Blount    AL

# %%
fips_df['Name']=fips_df['Name'].upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-f22fdc174a3c> in <module>
# ----> 1 fips_df['Name']=fips_df['Name'].upper()
#
# /opt/anaconda3/envs/PythonData/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'Series' object has no attribute 'upper'
